# %% [markdown]
# # Model creation

# %%
import sys
import os
parent_dir = os.path.dirname(os.getcwd())
sys.path.insert(0, parent_dir)
import src

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import glob

# %%
# First run the targets `data`, `features`

# %%
data = pd.read_csv('../data/features/features.csv')

# %%
data
# Out:
#                                                  file   activity  \
# 0   tiq004(5)_youtube_1x_vpn_windows_clean_2020103...  streaming
# 1      mhrowlan_netflix_1x_vpn_mac_clean_20201101.csv  streaming
# 2   pgaddiso-youtube-1x-720p-vpn-linux-clean-20201...  streaming
# 3   arv020(3)-youtube[480]-1x-vpn-mac-clean-202011...  streaming
# 4            stdoan-novideo-vpn-windows-20201029b.csv   browsing
# ..                                                ...        ...
# 89     dagong-youtube-1x-vpn-mac-clean-20201031-0.csv  streaming
# 90  pgaddiso-youtube-1x-720p-vpn-linux-clean-20201...  streaming
# 91  imnemato-youtube[1080p]-1x-vpn-mac-clean-20201...  streaming
# 92     maqader-netflix-1x-vpn-mac-clean-20201102d.csv  streaming
# 93  zij034(1)_youtube_1x_xpn_windows_clean_2020110...  streaming
#
#     mean_packet_size  mean_inter_packet_delay  send_receive_ratio
# 0         670.925799                10.991373            1.173167
# ...

# %%
data[data.activity == 'browsing']
# Out:
#                                            file  activity  mean_packet_size  \
# 4      stdoan-novideo-vpn-windows-20201029b.csv  browsing       1001.070955
# 5   apristin-novideo-vpn-windows-20201109-0.csv  browsing        526.090190
# 15  apristin-novideo-vpn-windows-20201109-3.csv  browsing        274.178105
# 18  apristin-novideo-vpn-windows-20201109-2.csv  browsing        230.054090
# 32     stdoan-novideo-vpn-windows-20201029c.csv  browsing        924.575338
# 37  apristin-novideo-vpn-windows-20201109-4.csv  browsing        239.640119
# 46  apristin-novideo-vpn-windows-20201109-5.csv  browsing        416.977692
# 47      stdoan-novideo-vpn-windows-20201029.csv  browsing        928.787871
# 54  apristin-novideo-vpn-windows-20201109-1.csv  browsing        565.880635
# 58     stdoan-novideo-vpn-windows-20201029e.csv  browsing        832.321244
# 68     stdoan-novideo-vpn-windows-20201029f.csv  browsing        992.667215
# ...

# %%
data[data.activity == 'streaming']
# Out:
#                                                  file   activity  \
# 0   tiq004(5)_youtube_1x_vpn_windows_clean_2020103...  streaming
# 1      mhrowlan_netflix_1x_vpn_mac_clean_20201101.csv  streaming
# 2   pgaddiso-youtube-1x-720p-vpn-linux-clean-20201...  streaming
# 3   arv020(3)-youtube[480]-1x-vpn-mac-clean-202011...  streaming
# 6   chy238-amazonprime-1x-vpn-windows-clean-202011...  streaming
# ..                                                ...        ...
# 89     dagong-youtube-1x-vpn-mac-clean-20201031-0.csv  streaming
# 90  pgaddiso-youtube-1x-720p-vpn-linux-clean-20201...  streaming
# 91  imnemato-youtube[1080p]-1x-vpn-mac-clean-20201...  streaming
# 92     maqader-netflix-1x-vpn-mac-clean-20201102d.csv  streaming
# 93  zij034(1)_youtube_1x_xpn_windows_clean_2020110...  streaming
#
#     mean_packet_size  mean_inter_packet_delay  send_receive_ratio
# 0         670.925799                10.991373            1.173167
# ...

# %%
data.drop(columns=['file', 'activity'])
# Out:
#     mean_packet_size  mean_inter_packet_delay  send_receive_ratio
# 0         670.925799                10.991373            1.173167
# 1        1013.994522                12.666291            0.306943
# 2         916.141870                 9.803782            0.443712
# 3         824.730846                 6.763372            0.948253
# 4        1001.070955                 4.783543            0.450515
# ..               ...                      ...                 ...
# 89        885.451694                15.538369            0.504221
# 90        886.717138                 8.875833            0.524595
# 91       1110.218787                 3.764227            0.239321
# 92       1093.421915                 4.281634            0.250586
# 93        836.787814                 4.245334            0.695215
#
# [94 rows x 3 columns]

# %%
X = data.iloc[:,2:]
y = data.activity == 'streaming'

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
roc_auc_score(y_test, clf.predict(X_test))
# Out:
# 0.6666666666666667

# %% [markdown]
# It's consistently able to correctly classify a single browsing as browsing -- the rest are streaming.
